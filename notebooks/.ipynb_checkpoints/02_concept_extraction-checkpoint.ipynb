# %% [markdown]
# # 02 — VLM Concept Extraction (Stage 1)
#
# Runs frozen BiomedCLIP over every image in HAM10000, Derm7pt, Fitzpatrick17k, and DDI and saves a 9-dim concept probability bundle per dataset to `outputs/concept_vectors/`. Implements Section 5.1.

# %%
import sys, subprocess
print("kernel python:", sys.executable)
print("sys.path[0:3]:", sys.path[:3])
try:
    import open_clip
    print("open_clip OK:", open_clip.__file__)
except ImportError as e:
    print("open_clip NOT FOUND in this kernel:", e)
# Out:
# kernel python: /opt/anaconda3/bin/python
# sys.path[0:3]: ['/Users/deepesh/Documents/Claude/Projects/AIH Final/vlm-cbm-derm-fairness', '/opt/anaconda3/lib/python313.zip', '/opt/anaconda3/lib/python3.13']
# open_clip NOT FOUND in this kernel: No module named 'open_clip'

# %%
import os, sys, yaml, logging
from pathlib import Path
PROJECT_ROOT = Path(os.getcwd())
if PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.insert(0, str(PROJECT_ROOT))
os.chdir(PROJECT_ROOT)

from torch.utils.data import DataLoader

from src.data.datasets import build_dataset, default_collate
from src.data.transforms import biomedclip_eval_transform
from src.models.concept_predictor import (
    BiomedCLIPConceptPredictor, CONCEPT_IDS, save_concept_bundle,
)
from src.utils import get_device, describe_device, dataloader_kwargs, seed_everything

logging.basicConfig(level=logging.INFO)
cfg = yaml.safe_load((PROJECT_ROOT / 'config.yaml').read_text())
paths = cfg['paths']
seed_everything(cfg.get('seed', 42))
device = get_device()
print('device:', describe_device(device))
# Out:
# device: mps (Apple arm64)

# %%
# Load BiomedCLIP (falls back to CLIP-ViT-B-32 if BiomedCLIP weights unavailable)
predictor = BiomedCLIPConceptPredictor(
    model_hub_id=cfg['vlm']['open_clip_hub_id'],
    device=device,
)
print('Loaded:', predictor.model_hub_id)
print('Concepts:', CONCEPT_IDS)
# Out:
# WARNING:src.models.concept_predictor:Could not load BiomedCLIP (No module named 'open_clip'). Falling back to hf-hub:laion/CLIP-ViT-B-32-laion2B-s34B-b79K.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/Documents/Claude/Projects/AIH Final/vlm-cbm-derm-fairness/src/models/concept_predictor.py:143, in BiomedCLIPConceptPredictor.__init__(self, model_hub_id, device, prompts, temperature, fallback_hub_id)
#     142 try:
# --> 143     self.model, self.preprocess, self.tokenizer = _load_open_clip(
#     144         model_hub_id, self.device
#     145     )
#     146     self.model_hub_id = model_hub_id
#
# File ~/Documents/Claude/Projects/AIH Final/vlm-cbm-derm-fairness/src/models/concept_predictor.py:112, in _load_open_clip(model_hub_id, device)
#     111 """Load a BiomedCLIP / CLIP backbone via the OpenCLIP API."""
# --> 112 import open_clip
#     113 logger.info("Loading OpenCLIP backbone: %s", model_hub_id)
#
# ModuleNotFoundError: No module named 'open_clip'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Load BiomedCLIP (falls back to CLIP-ViT-B-32 if BiomedCLIP weights unavailable)
# ----> 2 predictor = BiomedCLIPConceptPredictor(
#       3     model_hub_id=cfg['vlm']['open_clip_hub_id'],
#       4     device=device,
#       5 )
#       6 print('Loaded:', predictor.model_hub_id)
#       7 print('Concepts:', CONCEPT_IDS)
#
# File ~/Documents/Claude/Projects/AIH Final/vlm-cbm-derm-fairness/src/models/concept_predictor.py:152, in BiomedCLIPConceptPredictor.__init__(self, model_hub_id, device, prompts, temperature, fallback_hub_id)
#     147 except Exception as exc:
#     148     logger.warning(
#     149         "Could not load BiomedCLIP (%s). Falling back to %s.",
#     150         exc, fallback_hub_id,
#     151     )
# --> 152     self.model, self.preprocess, self.tokenizer = _load_open_clip(
#     153         fallback_hub_id, self.device
#     154     )
#     155     self.model_hub_id = fallback_hub_id
#     157 # `logit_scale` is a learned temperature exp(logit_scale). Honour the
#     158 # pretrained value unless the caller overrides.
#
# File ~/Documents/Claude/Projects/AIH Final/vlm-cbm-derm-fairness/src/models/concept_predictor.py:112, in _load_open_clip(model_hub_id, device)
#     110 def _load_open_clip(model_hub_id: str, device: torch.device):
#     111     """Load a BiomedCLIP / CLIP backbone via the OpenCLIP API."""
# --> 112     import open_clip
#     113     logger.info("Loading OpenCLIP backbone: %s", model_hub_id)
#     114     model, _, preprocess = open_clip.create_model_from_pretrained(model_hub_id)
#
# ModuleNotFoundError: No module named 'open_clip'

# %%
# Run extraction per dataset, save as .npz bundles
transform = biomedclip_eval_transform(cfg['vlm']['image_size'])
out_dir = PROJECT_ROOT / paths['concept_vectors_dir']
out_dir.mkdir(parents=True, exist_ok=True)

loader_kwargs = dataloader_kwargs(device=device)

for name, root in paths['datasets'].items():
    root = PROJECT_ROOT / root
    if not root.exists():
        print(f'[skip] {name}: {root} missing')
        continue
    try:
        ds = build_dataset(name, root=root, transform=transform)
    except Exception as e:
        print(f'[skip] {name}: {e}')
        continue
    if len(ds) == 0:
        print(f'[skip] {name}: empty dataset (images missing?)')
        continue
    print(f'{name}: {len(ds)} images')
    loader = DataLoader(
        ds, batch_size=cfg['vlm']['batch_size'],
        shuffle=False, collate_fn=default_collate, **loader_kwargs,
    )
    bundle = predictor.predict_dataset(loader)
    save_concept_bundle(out_dir / f'concepts_{name}.npz', bundle)
    print(f'saved -> {out_dir / f"concepts_{name}.npz"}')
# Out:
# ham10000: 10015 images
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 26
#      21 print(f'{name}: {len(ds)} images')
#      22 loader = DataLoader(
#      23     ds, batch_size=cfg['vlm']['batch_size'],
#      24     shuffle=False, collate_fn=default_collate, **loader_kwargs,
#      25 )
# ---> 26 bundle = predictor.predict_dataset(loader)
#      27 save_concept_bundle(out_dir / f'concepts_{name}.npz', bundle)
#      28 print(f'saved -> {out_dir / f"concepts_{name}.npz"}')
#
# NameError: name 'predictor' is not defined

# %%
# Quick sanity: concept AUROC on Derm7pt supervised concepts
import numpy as np
from src.evaluation.metrics import per_concept_auroc
from src.models.concept_predictor import load_concept_bundle

p = out_dir / 'concepts_derm7pt.npz'
if p.exists():
    b = load_concept_bundle(p)
    aur = per_concept_auroc(b['concepts'], b['concept_labels'], CONCEPT_IDS)
    for k, v in aur.items():
        print(f'{k:20s}  AUROC={v:.3f}' if not np.isnan(v) else f'{k:20s}  (no GT)')
